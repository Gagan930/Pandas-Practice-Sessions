# %%
import pandas as pd

# %%
dict1 ={'Name': ['Priyang', 'Aadhya', 'Krisha', 'Vedant', 'Parshv','Mittal', 'Archana'],
'Marks': [98,89,99,87,90,83,99],
'Gender': ['Male', 'Female', 'Female', 'Male', 'Male','Female', 'Female']
       }

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# ## Display top three rows

# %%
df.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %% [markdown]
# ## Check the last three rows of the dataset

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# ## Find Shape of Our Dataset (Number of Rows & Number of Columns)

# %%
df.shape
# Out:
# (7, 3)

# %%
print(f"Number or rows : {df.shape[0]} and Number of columns : {df.shape[1]}")
# Out:
# Number or rows : 7 and Number of columns : 3

# %% [markdown]
# ## Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      str
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 380.0 bytes

# %% [markdown]
# ## Check null values in the dataset

# %%
df.isnull().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %% [markdown]
# ## Get overall statistics about the dataset

# %%
df.describe()
# Out:
#            Marks
# count   7.000000
# mean   92.142857
# std     6.491753
# min    83.000000
# 25%    88.000000
# 50%    90.000000
# 75%    98.500000
# max    99.000000

# %%
# here its calculating all of the stats for quatitative data only which is "marks" columns , if we want to include every column

df.describe(include="all")
# Out:
#            Name      Marks  Gender
# count         7   7.000000       7
# unique        7        NaN       2
# top     Priyang        NaN  Female
# freq          1        NaN       4
# mean        NaN  92.142857     NaN
# std         NaN   6.491753     NaN
# min         NaN  83.000000     NaN
# 25%         NaN  88.000000     NaN
# 50%         NaN  90.000000     NaN
# 75%         NaN  98.500000     NaN
# max         NaN  99.000000     NaN

# %% [markdown]
# ## Find unique values from the Gender column

# %%
df["Gender"].unique()
# Out:
# <ArrowStringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %% [markdown]
# ## Find the Number of Unique values from the Gender column

# %%
# To find the number of unique we can use method "nunique"

df["Gender"].nunique()
# Out:
# 2

# %% [markdown]
# ## Display Count of Unique Values in Gender Column

# %%
# Count of unique values ka mtlb hota hai, har value kitni kitni baar aayi hai

df["Gender"].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %% [markdown]
# ## Find Total Number of Students Having Marks Between 90 To 100 (Inclusive) Using Between Method

# %%
bool_array = df[df["Marks"] >= 90] & df["Marks"] <= 100
# Out:
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\arrays\arrow\array.py:1025, in ArrowExtensionArray._evaluate_op_method(self, other, op, arrow_funcs)
#    1024 try:
# -> 1025     result = pc_func(self._pa_array, other)
#    1026 except pa.ArrowNotImplementedError as err:
#
# File D:\Anaconda\Lib\site-packages\pyarrow\compute.py:252, in _make_generic_wrapper.<locals>.wrapper(memory_pool, *args)
#     251     return Expression._call(func_name, list(args))
# --> 252 return func.call(args, None, memory_pool)
#
# File D:\Anaconda\Lib\site-packages\pyarrow\_compute.pyx:399, in pyarrow._compute.Function.call()
#
# File D:\Anaconda\Lib\site-packages\pyarrow\error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File D:\Anaconda\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowNotImplementedError: Function 'and_kleene' has no kernel matching input types (large_string, double)
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 bool_array = df[df["Marks"] >= 90] & df["Marks"] <= 100
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\arraylike.py:72, in OpsMixin.__and__(self, other)
#      70 @unpack_zerodim_and_defer("__and__")
#      71 def __and__(self, other):
# ---> 72     return self._logical_method(other, operator.and_)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:9139, in DataFrame._arith_method(self, other, op)
#    9136 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    9138 with np.errstate(all="ignore"):
# -> 9139     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    9140 return self._construct_result(new_data, other=other)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:9182, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    9176     assert self.columns.equals(right.columns)
#    9177     # TODO: The previous assertion `assert right._indexed_same(self)`
#    9178     #  fails in cases with empty columns reached via
#    9179     #  _frame_arith_method_with_reindex
#    9180
#    9181     # TODO operate_blockwise expects a manager of the same type
# -> 9182     bm = self._mgr.operate_blockwise(
#    9183         right._mgr,
#    9184         array_op,
#    9185     )
#    9186     return self._constructor_from_mgr(bm, axes=bm.axes)
#    9188 elif isinstance(right, Series) and axis == 1:
#    9189     # axis=1 means we want to operate row-by-row
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:1666, in BlockManager.operate_blockwise(self, other, array_op)
#    1662 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1663     """
#    1664     Apply array_op blockwise with another (aligned) BlockManager.
#    1665     """
# -> 1666     return operate_blockwise(self, other, array_op)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\ops\array_ops.py:447, in logical_op(left, right, op)
#     443 rvalues = right
#     445 if should_extension_dispatch(lvalues, rvalues):
#     446     # Call the method on lvalues
# --> 447     res_values = op(lvalues, rvalues)
#     449 else:
#     450     if isinstance(rvalues, np.ndarray):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\arraylike.py:72, in OpsMixin.__and__(self, other)
#      70 @unpack_zerodim_and_defer("__and__")
#      71 def __and__(self, other):
# ---> 72     return self._logical_method(other, operator.and_)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\arrays\arrow\array.py:1055, in ArrowExtensionArray._logical_method(self, other, op)
#    1053     return op(other, self.astype(bool))
#    1054 else:
# -> 1055     return self._evaluate_op_method(other, op, ARROW_LOGICAL_FUNCS)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\arrays\arrow\array.py:1027, in ArrowExtensionArray._evaluate_op_method(self, other, op, arrow_funcs)
#    1025     result = pc_func(self._pa_array, other)
#    1026 except pa.ArrowNotImplementedError as err:
# -> 1027     raise TypeError(self._op_method_error_message(other_original, op)) from err
#    1028 return self._from_pyarrow_array(result)
#
# TypeError: operation 'and_' not supported for dtype 'str' with dtype 'float64'

# %%
"
